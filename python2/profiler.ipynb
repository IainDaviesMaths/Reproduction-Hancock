# %%
# %%python2
# from PlotFigure2 import main
# from LearningProcess import LearningProcess
# main(2000)
# Out:
# 0	/	2000
# 10	/	2000
# 20	/	2000
# 30	/	2000
# 40	/	2000
# 50	/	2000
# 60	/	2000
# 70	/	2000
# 80	/	2000
# 90	/	2000
# 100	/	2000
# 110	/	2000
# 120	/	2000
# 130	/	2000
# 140	/	2000
# 150	/	2000
# 160	/	2000
# 170	/	2000
# 180	/	2000
# 190	/	2000
# 200	/	2000
# 210	/	2000
# 220	/	2000
# 230	/	2000
# 240	/	2000
# 250	/	2000
# 260	/	2000
# 270	/	2000
# 280	/	2000
# 290	/	2000
# 300	/	2000
# 310	/	2000
# 320	/	2000
# 330	/	2000
# 340	/	2000
# 350	/	2000
# 360	/	2000
# 370	/	2000
# 380	/	2000
# 390	/	2000
# 400	/	2000
# 410	/	2000
# 420	/	2000
# 430	/	2000
# 440	/	2000
# 450	/	2000
# 460	/	2000
# 470	/	2000
# 480	/	2000
# 490	/	2000
# 500	/	2000
# 510	/	2000
# 520	/	2000
# 530	/	2000
# 540	/	2000
# 550	/	2000
# 560	/	2000
# 570	/	2000
# 580	/	2000
# 590	/	2000
# 600	/	2000
# 610	/	2000
# 620	/	2000
# 630	/	2000
# 640	/	2000
# 650	/	2000
# 660	/	2000
# 670	/	2000
# 680	/	2000
# 690	/	2000
# 700	/	2000
# 710	/	2000
# 720	/	2000
# 730	/	2000
# 740	/	2000
# 750	/	2000
# 760	/	2000
# ...

# %%
# %load_ext line_profiler
# %lprun
from PlotFigure2 import main
from LearningProcess import LearningProcess
# %lprun -f LearningProcess main(100)
# from sagerupdate import sagerupdate
# %lprun -f sagerupdate main(100)
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# 0	/	100
# 10	/	100
# 20	/	100
# 30	/	100
# 40	/	100
# 50	/	100
# 60	/	100
# 70	/	100
# 80	/	100
# 90	/	100

# %%
import IPython.display as ipd
ipd.Image('Figure2.png')
